# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import arviz as az

# %%
# generate observed data
MEAN_DIST_LAMBDA = st.norm(loc=3, scale=1).rvs(size=1000)
ERROR = st.norm(loc=2, scale=.5).rvs(100)

# %%
X = np.sort(MEAN_DIST_LAMBDA)
plt.plot(X, linestyle='', marker='x')

# %%
def log_prior(theta):
    mu = theta
    if 0 < mu < 1:
        return 0
    return -np.inf

def log_likelihood(theta, x, y, yerr):
# Out:
#   Cell In[4], line 7
#     def log_likelihood(theta, x, y, yerr):
#                                           ^
# SyntaxError: incomplete input
