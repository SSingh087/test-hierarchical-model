# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import arviz as az

# %%
# generate observed data
X = st.norm(loc=2, scale=1).rvs(size=1000)

# %%
plt.hist(X)
# Out:
# (array([  2.,   5.,  29., 121., 236., 252., 210.,  96.,  34.,  15.]),
#  array([-1.63136703, -0.97546342, -0.31955981,  0.3363438 ,  0.99224742,
#          1.64815103,  2.30405464,  2.95995825,  3.61586187,  4.27176548,
#          4.92766909]),
#  <BarContainer object of 10 artists>)
